# %%
import sys
sys.path.append("/sdf/group/ad/beamphysics/jytang/cavity_genesis4_20keV/cavity_genesis4") 
from genesis4.lume_genesis_JT import Genesis4
from genesis4.lume_genesis_JT.plot import plot_stats
import numpy as np
import matplotlib.pyplot as plt
import os
from constants import *
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %% [markdown]
# ## Load archive

# %%
basedir = '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA'
# basedir = './run3_moreheater/'
files = np.array(os.listdir(basedir))
files = files[np.array(['K' in file for file in files])]
files = files[np.array(['n4' in file for file in files])]

files = files[np.array(['taper0.0' in file for file in files])]

files = files[np.array(['.out.h5'    in file for file in files])]

#files = files[np.array(['h5'   in file for file in files])]
#files = files[np.array(['Run2'   in file for file in files])]

files = files[np.array(['fld'  not in file for file in files])]
files = files[np.array(['lat'  not in file for file in files])]
files = files[np.array(['beam'  not in file for file in files])]
print(files)
files = files[np.array(['in'  not in file for file in files])]
files = files[np.array(['par'  not in file for file in files])]
#files = files[np.array(['out'  not in file for file in files])]
files = files[np.array(['err'  not in file for file in files])]
files = np.sort(files)
files
# Out:
# ['K0.4335_taper0.01_n4.out.h5']
# array(['K0.4335_taper0.01_n4.out.h5'], dtype='<U35')

# %%
Glist = []
for file in files:
    print(file)
    G = Genesis4(workdir = basedir, use_temp_dir = False)
    G.load_archive(basedir + '/' + file)
    Glist.append(G)
# Out:
# K0.4335_taper0.01_n4.out.h5

# %%
G.output_info()
# Out:
# Output data
#
# key                       value              unit
# --------------------------------------------------
# Beam/LSCfield             array: (4289, 480)  eV/m
# Beam/SSCfield             array: (4289, 480)  eV/m
# Beam/alphax               array: (1, 480)    rad
# Beam/alphay               array: (1, 480)    rad
# Beam/betax                array: (1, 480)    m
# Beam/betay                array: (1, 480)    m
# Beam/bunching             array: (4289, 480)
# Beam/bunchingphase        array: (4289, 480)  rad
# Beam/current              array: (4289, 480)  A
# Beam/efield               array: (4289, 480)  eV/m
# Beam/emax                 array: (4289, 480)  m_ec^2
# Beam/emin                 array: (4289, 480)  m_ec^2
# Beam/emitx                array: (1, 480)    m
# Beam/emity                array: (1, 480)    m
# Beam/energy               array: (4289, 480)  m_ec^2
# Beam/energyspread         array: (4289, 480)  m_ec^2
# Beam/pxmax                array: (4289, 480)  rad
# Beam/pxmin                array: (4289, 480)  rad
# Beam/pxposition           array: (4289, 480)  rad
# Beam/pymax                array: (4289, 480)  rad
# Beam/pymin                array: (4289, 480)  rad
# Beam/pyposition           array: (4289, 480)  rad
# Beam/wakefield            array: (4289, 480)  eV/m
# Beam/xmax                 array: (4289, 480)  m
# Beam/xmin                 array: (4289, 480)  m
# Beam/xposition            array: (4289, 480)  m
# Beam/xsize                array: (4289, 480)  m
# Beam/ymax                 array: (4289, 480)  m
# Beam/ymin                 array: (4289, 480)  m
# Beam/yposition            array: (4289, 480)  m
# Beam/ysize                array: (4289, 480)  m
# Field/dgrid               4.011111111111111e-06
# Field/intensity-farfield  array: (4289, 480)  W/rad^2
# Field/intensity-nearfield array: (4289, 480)  W/m^2
# Field/ngrid               181.0
# Field/phase-farfield      array: (4289, 480)  rad
# Field/phase-nearfield     array: (4289, 480)  rad
# Field/power               array: (4289, 480)  W
# Field/xdivergence         array: (4289, 480)  rad
# Field/xpointing           array: (4289, 480)  rad
# Field/xposition           array: (4289, 480)  m
# Field/xsize               array: (4289, 480)  m
# Field/ydivergence         array: (4289, 480)  rad
# Field/ypointing           array: (4289, 480)  rad
# Field/yposition           array: (4289, 480)  m
# Field/ysize               array: (4289, 480)  m
# Global/frequency          array: (480,)
# Global/gamma0             15655.577
# Global/lambdaref          6.30524765e-11
# Global/one4one            0.0
# Global/s                  array: (480,)
# Global/sample             200.0
# Global/scan               0.0
# Global/slen               6.053037743999999e-06
# Global/time               1.0
# Lattice/aw                array: (4288,)
# Lattice/ax                array: (4288,)
# Lattice/ay                array: (4288,)
# Lattice/chic_angle        array: (4288,)
# Lattice/chic_lb           array: (4288,)
# Lattice/chic_ld           array: (4288,)
# Lattice/chic_lt           array: (4288,)
# Lattice/cx                array: (4288,)
# Lattice/cy                array: (4288,)
# Lattice/dz                array: (4288,)
# Lattice/gradx             array: (4288,)
# Lattice/grady             array: (4288,)
# Lattice/ku                array: (4288,)
# Lattice/kx                array: (4288,)
# Lattice/ky                array: (4288,)
# Lattice/phaseshift        array: (4288,)
# Lattice/qf                array: (4288,)
# Lattice/qx                array: (4288,)
# Lattice/qy                array: (4288,)
# Lattice/slippage          array: (4288,)
# Lattice/z                 array: (4288,)
# Lattice/zplot             array: (4289,)
# Meta/Beamdumps/ndumps     0
# Meta/Fielddumps/ndumps    0
# Meta/HOST                 Undefined
# Meta/InputFile            long str:  &setup rootname = K...
# Meta/LatticeFile          long str: UD0: Undulator = {la...
# Meta/TimeStamp            Fri Apr  5 16:44:08 2024
#
# Meta/User                 jytang
# Meta/Version/Beta         0.0
# Meta/Version/Build_Info   Compiled by conda at 2024-01-11 18:02:26 [UTC] from Git Commit ID: 226c27d5b1b045a8195218d2ce5d63aaa10537c7
# Meta/Version/Major        4.0
# Meta/Version/Minor        6.0
# Meta/Version/Revision     6.0
# Meta/cwd                  /sdf/scratch/users/j/jytang/tmpfjkll_9l
# Meta/mpisize              120.0
#
# field_files               ['/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n1_field_transmit_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n4_seed_init.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n3_seed_init.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n3_field_recirc_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n3_field_transmit_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n2_field_recirc_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n2_field_transmit_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n1_seed.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n1_field_recirc_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n3.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n0_field_recirc_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n1.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n0_field_transmit_round0.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n2.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n2_seed_init.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n2_seed.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n4_seed.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n4.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n1_seed_init.fld.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/n3_seed.fld.h5']
# outfile                   /sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n4.out.h5
# particle_files            ['/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n0.par.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n3.par.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n1.par.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n2.par.h5', '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad0_8_5kA/K0.4335_taper0.01_n4.par.h5']

# %%
gam0 = G.output['Global/gamma0']
xlamds = G.output['Global/lambdaref']
zsep = G.output['Global/sample']
dgird = G.output['Field/dgrid']
ncar = G.output['Field/ngrid']
h_Plank = H_PLANK;      # Plank constant [eV-sec]
c_speed  = CSPEED;           # speed of light[m/sec]
hw0 = h_Plank * c_speed / xlamds
dt = xlamds*zsep/c_speed

# %%
amx = 0
amin =  float('inf')
for G in Glist:
    z = G.output['Lattice/z']
    aw = G.output['Lattice/aw']
    amx = np.amax((amx,np.amax(aw[aw>0])))
    amx += amx * 1e-3
    amin = np.amin((amin,np.amin(aw[aw>0])))
    amin -= amin*1e-3
    plt.plot(z, aw)
print(amin)
plt.ylim([amin, amx])
# Out:
# 0.428735835
# (0.428735835, 0.43393349999999997)

# %% [markdown]
# ## Plot profile of ebeam

# %%
energy_init = G.output['Beam/energy'][0, :]
energy_final = G.output['Beam/energy'][-1,:]
current = G.output['Beam/current']
currlist = current[0,:]
s = G.output['Global/s']
plt.plot(s/3e8*1e15, energy_init*0.511, color = 'C0', label = 'initial')
plt.plot(s/3e8*1e15, energy_final*0.511, color = 'C1', label = 'final')
plt.legend()
ax = plt.gca()
ax2 = ax.twinx()
ax2.plot(s/3e8*1e15, currlist, color = 'C2')
ax.set_xlabel('Time (fs)')
ax2.set_ylabel('Current (I)', color = 'C2')
ax.set_ylabel('energy(MeV)')
# Out:
# Text(0, 0.5, 'energy(MeV)')

# %% [markdown]
# ## Plot Power Gain

# %%
num_photon_list = []
for count, G in enumerate(Glist):
    z = G.output['Lattice/zplot']
    label = G.output['outfile'].split('/')[-1]
    power = np.amax(G.output['Field/power'], axis = 1)
    energy = np.sum(G.output['Field/power'], axis = 1)*dt
    num_photon = energy/(hw0*1.60218e-19)
    num_photon_list.append(num_photon[-1])
    plt.plot(z, power, label = label)
    plt.yscale('log')
plt.legend()
plt.xlabel('z (m)')
#plt.ylabel('Number of photons')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
G.plot('field_energy', yscale='log', y2 = ['beam_xsize', 'beam_ysize'], ylim2=(0, 40e-6))

# %% [markdown]
# ## Plot Power Profile

# %%
G.output['Field/power'].shape
# Out:
# (4289, 480)

# %%
for count, G in enumerate(Glist):
    s = G.output['Global/s']
    label = G.output['outfile'].split('/')[0]
    intensity = G.output['Field/power'][-1,:]
    plt.plot(s/3e8, intensity/1e9, label = label)
    break
    #plt.yscale('log')
    #ax = plt.gca()
    #ax2 = ax.twinx()
    #ax2.plot(s/3e8, phase)
plt.xlabel('Time (fs)')
plt.ylabel('Power (GW)')
plt.legend(fontsize = 5)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Plot spectrum

# %%
for count, G in enumerate(Glist):
    s = G.output['Global/s']
    label = G.output['outfile'].split('/')[-1]
    intensity = G.output['Field/intensity-nearfield'][-1,:]
    phase = G.output['Field/phase-nearfield'][-1, :]
    

    h_Plank = 4.135667696e-15
    npad = 10000
    cspeed = 299792458
    nslice = intensity.shape[0]
    
    nslice_padded = nslice + 2*npad
    s = np.arange(nslice)*dt
    s2 = np.arange(nslice_padded) * dt
    s_fs2 = s2*1e15
    hw0_eV = h_Plank * cspeed / xlamds
    Dhw_eV = h_Plank / dt 
    hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)

    central = intensity *np.exp(1j*phase)
    central_padded = np.pad(central, (npad, npad))
    ftfld = np.fft.fftshift(np.fft.fft(central_padded))
    spectrum = np.abs(ftfld)**2
    plt.plot(hws, spectrum)
    plt.xlabel('Photon Enerygy (eV)')
    plt.ylabel('Spectral Intensity')
    plt.xlim([19653.2, 19674])
    plt.legend(fontsize = 5)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Load field

# %%
import h5py
from genesis4.lume_genesis_JT.readers import load_genesis4_fields
from recirculation.plot_fld import *

# %%
fld_filename = '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad1_2_5kA/K0.4335_taper0.01_n4.fld.h5'
with h5py.File(fld_filename, 'r') as h5:
    dfl, param = load_genesis4_fields(h5)
c_speed = 299792458
dt = param['slicespacing']/c_speed
plot_fld_power(dfl, dt, ax=None, saveFilename=None, showPlotQ=True, savePlotQ=True, logScaleQ=False)
plot_fld_marginalize_t(dfl, dgrid = param['gridsize']*param['gridpoints']/2, dt=dt, saveFilename=None, showPlotQ=True, savePlotQ=True)
# Out:
# norm = 17408434292379.914     energy = 732.3  uJ    t , y  mean = 0.3 fs , 0.1 um      t , y  rms = 5.7 fs , 38.8 um     wt , wy = 11.4 fs , 77.6 um     t , y  fwhm = nan fs , nan um
# norm = 17408434292379.916     energy = 732.3  uJ    x , y  mean = 0.0 um , 0.1 um      x , y  rms = 36.1 um , 35.2 um     wx , wy = 72.2 um , 70.4 um     x , y  fwhm = nan um , nan um

# %%
fld_filename = '/sdf/data/ad/ard/u/jytang/cavity_genesis4_20keV/data_qgrad1_2_5kA/n5_seed_init.fld.h5'
with h5py.File(fld_filename, 'r') as h5:
    dfl, param = load_genesis4_fields(h5)
c_speed = 299792458
dt = param['slicespacing']/c_speed
plot_fld_power(dfl, dt, ax=None, saveFilename=None, showPlotQ=True, savePlotQ=True, logScaleQ=False)
plot_fld_marginalize_t(dfl, dgrid = param['gridsize']*param['gridpoints']/2, dt=dt, saveFilename=None, showPlotQ=True, savePlotQ=True)
# Out:
# norm = 685949712554.1621     energy = 28.9  uJ    t , y  mean = -73.8 fs , 0.1 um      t , y  rms = 249.8 fs , 31.6 um     wt , wy = 499.6 fs , 63.2 um     t , y  fwhm = nan fs , nan um
# norm = 685949712554.1621     energy = 28.9  uJ    x , y  mean = 8.6 um , 0.1 um      x , y  rms = 62.5 um , 28.7 um     wx , wy = 125.0 um , 57.4 um     x , y  fwhm = nan um , nan um

# %% [markdown]
# ## Plot spectrum from field

# %%
cspeed =299792458
h_Plank = 4.135667696e-15
npad = 20000
xlamds = param['wavelength']
nslice = dfl.shape[2]
ncar = dfl.shape[0]
nslice_padded = nslice + 2*npad
s = np.arange(nslice)*dt
s2 = np.arange(nslice_padded) * dt
s_fs2 = s2*1e15
hw0_eV = h_Plank * cspeed / xlamds
Dhw_eV = h_Plank / dt 
hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)

central = dfl[ncar//2,  ncar//2, :]
central_padded = np.pad(central, (npad, npad))
ftfld = np.fft.fftshift(np.fft.fft(central_padded))
spectrum = np.abs(ftfld)**2

# %%
plt.plot(hws, spectrum)
plt.xlim([19653, 19664.5])
#plt.xlim([19600, 19690])
# Out:
# (19653.0, 19664.5)

# %%
from genesis.version4 import parsers, writers, readers
import h5py
cspeed =299792458
h_Plank = 4.135667696e-15
npad = 10000
spectrum_list = []

for count, G in enumerate(Glist):
    ncar = int(G.output['Field/ngrid'])
    dgrid = G.output['Field/dgrid']
    xlamds = G.output['Global/lambdaref']
    sample = G.output['Global/sample']
    dt = xlamds*sample/cspeed

    #phase_nearfield = G.output['Field/phase-nearfield'][-1, :]
    #intensity_nearfield = G.output['Field/intensity-nearfield'][-1, :]
    G.load_fields()
    dfl = G.field[files[count]]['dfl']
    param = G.field[files[count]]['param']
    
    #central = dfl[ncar//2 +1, ncar//2 + 1, :]
    nslice = dfl.shape[2]
    nslice_padded = nslice + 2*npad
    s = np.arange(nslice)*dt
    s2 = np.arange(nslice_padded) * dt
    s_fs2 = s2*1e15
    hw0_eV = h_Plank * cspeed / xlamds
    Dhw_eV = h_Plank / dt 
    hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)

    central_padded = np.pad(dfl, ((0,0), (0,0),(npad, npad)))
    ftfld = np.fft.fftshift(np.fft.fft(central_padded, axis = 2), axes = 2)
    spectrum = np.sum(np.abs(ftfld)**2, axis = (0, 1))

    spectrum_list.append((hws,spectrum))

# %%
count = 0
spec_ave = np.zeros(spectrum_list[0][1].shape)
for hws, spec in spectrum_list:
    plt.plot(hws, spec, label = files[count], alpha = 1.0)
    plt.xlim([9828,9835])
    plt.xlabel('Photon energy (eV)')
    count += 1
    spec_ave += spec
    #plt.legend()
spec_ave /= (count + 1)
#plt.plot(hws, spec_ave, color = 'k')

# %%
import pickle
pickle.dump((hws, spec_ave, spectrum_list), open( "./data/stage2/chirp40.p", "wb" ) )

# %%
## Get photon number within 100meV
ind_peak = np.argmax(spec_ave)
hws0 = hws[ind_peak]
ind = (hws < hws0 + 0.05)&(hws > hws0 - 0.05)
np.sum(spec[ind])/np.sum(spec)*np.sum(num_photon_list)/5/1e6
# Out:
# 50.242637289085934

# %%
[50e6, ]

# %%
for chirp in [0, 40, 80, 120]:
    data = pickle.load( open("./data/stage2/chirp" + str(chirp)+".p", "rb" ) )
    hws = data[0]
    spec_av = data[1]
    plt.plot(hws, spec_av, label = 'energy chirp=' + str(chirp) +'MeV/60fs')
    plt.xlim([9828,9835])
    plt.xlabel('photon energy (eV)')
    plt.ylabel('Spectral Intensity')
    plt.title('Spectrum averaged over 5 shots')
    plt.legend()

# %% [markdown]
# ## 2D plots

# %%
def make_zs_plot(pdat, zlist, slist_fs, currlist, energylist_init, energylist_fin, ax = None, label = ''):
    if not ax:
        fig, ax = plt.subplots()
    
    currlist_scaled = currlist - 0*np.min(currlist)
    currlist_scaled /= np.max(currlist_scaled)
    currlist_scaled *= np.max(zlist) - np.min(zlist)
    currlist_scaled += np.min(zlist)
    energylist_init_scaled = energylist_init - np.min(energylist_fin)
    energylist_init_scaled /= np.max(energylist_init_scaled)
    energylist_init_scaled *= np.max(zlist) - np.min(zlist)
    energylist_init_scaled += np.min(zlist)
    energylist_fin_scaled = energylist_fin - np.min(energylist_fin)
    energylist_fin_scaled /= np.max(energylist_fin_scaled)
    energylist_fin_scaled *= np.max(zlist) - np.min(zlist)
    energylist_fin_scaled += np.min(zlist)
    
    #pdat = np.reshape(np.array(outputdat.iloc[:,ia]), [int(outputdat.shape[0] / len(zlist)), len(zlist)]).T
    im = ax.imshow(pdat, interpolation = 'none', extent = [slist_fs[0], slist_fs[-1], zlist[0], zlist[-1]], origin = 'lower', aspect = 0.75*(slist_fs[-1] - slist_fs[0]) / (zlist[-1] - zlist[0]))
    ax.set_xlabel('$s$ (fs)')
    ax.set_ylabel('$z$ (m)')

    cbar = fig.colorbar(im, ax = ax)
    cbar.set_label(label, rotation = 270)
    ax.plot(slist_fs, currlist_scaled, 'w', alpha = 0.5, scalex = False, scaley = False);
    ax.plot(slist_fs, energylist_init_scaled, '#ff9900', alpha = 0.5, scalex = False, scaley = False);
    ax.plot(slist_fs, energylist_fin_scaled, '#ff9900', alpha = 0.25, scalex = False, scaley = False);

# %%
zlist = G.output['Lattice/zplot']
slist_fs = G.output['Global/s']/3e8*1e15
beam_energy = G.output['Beam/energy']
make_zs_plot(pdat = beam_energy, zlist = zlist, slist_fs = slist_fs, currlist = currlist, 
             energylist_init = energy_init, energylist_fin = energy_final, label = 'ebeam/energy')

beam_xposition =G.output['Beam/xposition']

make_zs_plot(pdat =beam_xposition, zlist = zlist, slist_fs = slist_fs, currlist = currlist, 
             energylist_init = energy_init, energylist_fin = energy_final, label = 'ebeam/xposition')

beam_yposition = G.output['Beam/yposition']
beam_xsize = G.output['Beam/xsize']
make_zs_plot(pdat =beam_xsize, zlist = zlist, slist_fs = slist_fs, currlist = currlist, 
             energylist_init = energy_init, energylist_fin = energy_final, label = 'ebeam/xsize')

beam_ysize = G.output['Beam/ysize']
make_zs_plot(pdat =beam_ysize, zlist = zlist, slist_fs = slist_fs, currlist = currlist, 
             energylist_init = energy_init, energylist_fin = energy_final, label = 'ebeam/ysize')
beam_bunching = G.output['Beam/bunching']
field_xsize = G.output['Field/xsize']
field_ysize = G.output['Field/ysize']

# %% [markdown]
# ## Plot Spectrum

# %%
from genesis.version4 import parsers, writers, readers
import h5py
angle_list = []
spectrum_list = []
for count, G in enumerate(Glist):
    print(count)
    filename = './output_phase_10keV/K1.172_taper0.0_b' + str(detune[count]) + '.fld.h5'
    with h5py.File(filename, "r") as h5:
        dfl, param = readers.load_genesis4_fields(h5)
    cspeed =299792458
    h_Plank = 4.135667696e-15
    npad = 10000
    ncar = param['gridpoints']
    dgrid = param['gridsize']
    xlamds = param['wavelength']
    dt = param['slicespacing']/cspeed
    nslice = dfl.shape[2]
    central = dfl[ncar//2+1, ncar//2+1, :] 
    phase = np.angle(central)
    nslice_padded = nslice + 2*npad
    s = np.arange(nslice)*dt
    s2 = np.arange(nslice_padded) * dt
    s_fs2 = s2*1e15
    hw0_eV = h_Plank * cspeed / xlamds
    Dhw_eV = h_Plank / dt 
    hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)

    central_padded = np.pad(central, (npad, npad))
    ftfld = np.fft.fftshift(np.fft.fft(central_padded, axis = 0), axes = 0)
    spectrum = np.abs(ftfld)**2\

    angle_list.append(phase)
    spectrum_list.append(spectrum)
    
    plt.plot(hws, np.abs(ftfld)**2)
    plt.xlim([9827, 9835])
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 7
#       5 for count, G in enumerate(Glist):
#       6     print(count)
# ----> 7     filename = './output_phase_10keV/K1.172_taper0.0_b' + str(detune[count]) + '.fld.h5'
#       8     with h5py.File(filename, "r") as h5:
#       9         dfl, param = readers.load_genesis4_fields(h5)
#
# NameError: name 'detune' is not defined

# %%
dphase = []
for count, phase in enumerate(angle_list):
    plt.figure(1)
    plt.plot(s, np.unwrap(phase))
    phase1 = np.mean(phase[(s>35e-15)&(s<45e-15)])
    phase2 = np.mean(phase[(s>55e-15)&(s<65e-15)])
    dphase.append(phase1 - phase2)

plt.xlabel('Time (s)')
plt.ylabel('phase (rad)')
plt.figure(2)
plt.plot(detune, dphase, '.')
plt.xlabel('detune (1e-4)')
plt.ylabel('phase shift')
# Out:
# Text(0, 0.5, 'phase shift')

# %%
cspeed =299792458
h_Plank = 4.135667696e-15
npad = 1000

keys = sorted(G.field.keys())[0]
dfl = G.field[keys]['dfl']
nslice = dfl.shape[2]
param = G.field[keys]['param']
ncar = param['gridpoints']
dgrid = param['gridsize']
xlamds = param['wavelength']
dt = param['slicespacing']/cspeed

central = dfl[ncar//2+1, ncar//2+1, :] 
nslice_padded = nslice + 2*npad
s2 = np.arange(nslice_padded) * dt
s_fs2 = s2*1e15
hw0_eV = h_Plank * cspeed / xlamds
Dhw_eV = h_Plank / dt 
hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)

central_padded = np.pad(central, (npad, npad))
ftfld = np.fft.fftshift(np.fft.fft(central_padded, axis = 0), axes = 0)

plt.plot(hws, np.abs(ftfld)**2)
plt.xlim([1470, 1520])

# %%
np.random.randint(1,3, size = 10)
# Out:
# array([1, 1, 2, 1, 2, 2, 2, 2, 2, 1])

# %%
cspeed =299792458
h_Plank = 4.135667696e-15
npad = 1000
mask_center_eV = 1497

keys = sorted(G.field.keys())[0]
dfl = G.field[keys]['dfl']
nslice = dfl.shape[2]
param = G.field[keys]['param']
ncar = param['gridpoints']
dgrid = param['gridsize']
xlamds = param['wavelength']
dt = param['slicespacing']/cspeed

central = dfl[ncar//2+1, ncar//2+1, :] 
nslice_padded = nslice + 2*npad

s = np.arange(nslice) * dt
s_fs = s*1e15
s2 = np.arange(nslice_padded) * dt
s_fs2 = s2*1e15
hw0_eV = h_Plank * cspeed / xlamds
Dhw_eV = h_Plank / dt 
hws = hw0_eV + Dhw_eV / 2. * np.linspace(-1.,1., nslice_padded)


dfl_padded = np.pad(dfl, ( (0,0), (0,0), (npad, npad)))
ftfld = np.fft.fftshift(np.fft.fft(dfl_padded, axis = 2), axes = 2)


plt.figure(1)
plt.plot(s_fs, np.sum(np.abs(dfl )**2, axis = (0,1)))
plt.xlabel('Time(fs)')
plt.ylabel('power before filtering') 


plt.figure(2)
plt.plot(s_fs, np.angle(dfl[ncar//2 + 1, ncar//2+1, :] ))
plt.xlabel('Time(fs)')
plt.ylabel('phase before filtering') 
#plt.xlim([40,50])

plt.figure(3)
plt.plot(hws, np.sum(np.abs(ftfld)**2, axis = (0,1)) )
#plt.xlim([590,610])
plt.xlabel('Photon energy(eV)')
plt.ylabel('spectrum before filtering') 
plt.xlim([1470, 1520])


plt.figure(4)
mask_width_eV = 0.12/2.355
mask_eff = np.sqrt(0.1)
mask = mask_eff*np.exp(-1/2*(hws - mask_center_eV)**2/mask_width_eV**2)
ftfld_fltr = ftfld*mask[ np.newaxis, np.newaxis, :]
plt.plot(hws, np.sum(np.abs(ftfld_fltr)**2, axis = (0,1)),'.')
#plt.plot(hws,np.sum(np.abs(ftfld)**2, axis = (1,2)),'.')
plt.xlim([mask_center_eV-1, mask_center_eV+1])
plt.xlabel('Photon energy(eV)')
plt.ylabel('spectrum after filtering')

field_fltr = np.fft.ifft(np.fft.ifftshift(ftfld_fltr, axes = 2), axis = 2)
power = np.sum(np.abs(field_fltr )**2, axis = (0,1))
plt.figure(5)
plt.plot(s_fs2, power)
plt.xlabel('Time(fs)')
plt.ylabel('power after filtering')
# Out:
# Text(0, 0.5, 'power after filtering')

# %%
param['slicecount'] += npad*2

# %%
param
# Out:
# {'gridpoints': 301,
#  'gridsize': 1.3333333333333333e-05,
#  'refposition': 0.0,
#  'wavelength': 8.27e-10,
#  'slicecount': 2576,
#  'slicespacing': 3.308e-09}

# %%
import h5py
with h5py.File("./output/seed"+str(count)+".h5", "w") as f:
    for key in param:
        f.create_dataset(key, data = [param[key]])
    for i in range(field_fltr.shape[2]):
        key = 'slice' + "{:06d}".format(i)
        g = f.create_group(key)
        g.create_dataset('field-real', data = np.real(field_fltr[:,:, i].flatten()))
        g.create_dataset('field-imag', data = np.imag(field_fltr[:,:, i].flatten()))

# %%
i
# Out:
# 2575

# %%
G.output_info()
# Out:
# Output data
#
# key                       value              unit
# --------------------------------------------------
# Beam/alphax               array: (1, 512)    rad
# Beam/alphay               array: (1, 512)    rad
# Beam/betax                array: (1, 512)    m
# Beam/betay                array: (1, 512)    m
# Beam/bunching             array: (1351, 512)
# Beam/bunchingphase        array: (1351, 512)  rad
# Beam/current              array: (1, 512)    A
# Beam/efield               array: (1351, 512)  eV/m
# Beam/emitx                array: (1, 512)    m
# Beam/emity                array: (1, 512)    m
# Beam/energy               array: (1351, 512)
# Beam/energyspread         array: (1351, 512)
# Beam/pxposition           array: (1351, 512)  rad
# Beam/pyposition           array: (1351, 512)  rad
# Beam/xposition            array: (1351, 512)  m
# Beam/xsize                array: (1351, 512)  m
# Beam/yposition            array: (1351, 512)  m
# Beam/ysize                array: (1351, 512)  m
# Field/dgrid               1.3333333333333333e-05
# Field/intensity-farfield  array: (1351, 512)
# Field/intensity-nearfield array: (1351, 512)
# Field/ngrid               301
# Field/phase-farfield      array: (1351, 512)  rad
# Field/phase-nearfield     array: (1351, 512)  rad
# Field/power               array: (1351, 512)  W
# Field/xdivergence         array: (1351, 512)  rad
# Field/xpointing           array: (1351, 512)  rad
# Field/xposition           array: (1351, 512)  m
# Field/xsize               array: (1351, 512)  m
# Field/ydivergence         array: (1351, 512)  rad
# Field/ypointing           array: (1351, 512)  rad
# Field/yposition           array: (1351, 512)  m
# Field/ysize               array: (1351, 512)  m
# Field3/dgrid              1.3333333333333333e-05
# Field3/intensity-farfield array: (1351, 512)
# Field3/intensity-nearfield array: (1351, 512)
# Field3/ngrid              301
# Field3/phase-farfield     array: (1351, 512)  rad
# Field3/phase-nearfield    array: (1351, 512)  rad
# Field3/power              array: (1351, 512)  W
# Field3/xdivergence        array: (1351, 512)  rad
# Field3/xpointing          array: (1351, 512)  rad
# Field3/xposition          array: (1351, 512)  m
# Field3/xsize              array: (1351, 512)  m
# Field3/ydivergence        array: (1351, 512)  rad
# Field3/ypointing          array: (1351, 512)  rad
# Field3/yposition          array: (1351, 512)  m
# Field3/ysize              array: (1351, 512)  m
# Global/frequency          array: (512,)
# Global/gamma0             7827.789
# Global/lambdaref          1.55e-09
# Global/one4one            0.0
# Global/s                  array: (512,)
# Global/sample             10.0
# Global/scan               0.0
# Global/slen               7.936e-06
# Global/time               1.0
# Lattice/aw                array: (1440,)
# Lattice/ax                array: (1440,)
# Lattice/ay                array: (1440,)
# Lattice/chic_angle        array: (1440,)
# Lattice/chic_lb           array: (1440,)
# Lattice/chic_ld           array: (1440,)
# Lattice/chic_lt           array: (1440,)
# Lattice/cx                array: (1440,)
# Lattice/cy                array: (1440,)
# Lattice/dz                array: (1440,)
# Lattice/gradx             array: (1440,)
# Lattice/grady             array: (1440,)
# Lattice/ku                array: (1440,)
# Lattice/kx                array: (1440,)
# Lattice/ky                array: (1440,)
# Lattice/phaseshift        array: (1440,)
# Lattice/qf                array: (1440,)
# Lattice/qx                array: (1440,)
# Lattice/qy                array: (1440,)
# Lattice/slippage          array: (1440,)
# Lattice/z                 array: (1440,)
# Lattice/zplot             array: (1351,)
# Meta/Beamdumps/ndumps     0
# Meta/Fielddumps/ndumps    0
# Meta/HOST                 Undefined
# Meta/InputFile            long str:  &setup rootname = K...
# Meta/LatticeFile          long str: UD0: Undulator = {la...
# Meta/PWD                  /sdf/group/beamphysics/jytang/genesis/genesis4_test/output_800eV
# Meta/TimeStamp            Tue Aug  8 15:13:09 2023
#
# Meta/User                 jytang
# Meta/Version/Beta         1.0
# Meta/Version/Build_Info   compiled by rmargraf 20220107T1434 from git commit ID 143ebb0c848101bfeef5358ea8f392fcce13ee50 (+ uncommitted changes)
# Meta/Version/Major        4.0
# Meta/Version/Minor        5.0
# Meta/Version/Revision     1.0
# Meta/mpisize              64.0
#
# field_files               ['./output_800eV/K1.965_taper0.008_c.fld.h5', './output_800eV/K1.965_taper0.0_PS1.fld.h5', './output_800eV/K1.965_taper0.002_d.fld.h5', './output_800eV/K1.965_taper0.006_b.fld.h5', './output_800eV/K1.965_taper0.004_PS2.fld.h5', './output_800eV/K1.965_taper0.004_b.fld.h5', './output_800eV/K1.965_taper0.002_c.fld.h5', './output_800eV/K1.965_taper0.0_f.fld.h5', './output_800eV/K1.694_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.002_d.h3.fld.h5', './output_800eV/K1.965_taper0.01_c.h3.fld.h5', './output_800eV/K1.965_taper0.004_d.h3.fld.h5', './output_800eV/K1.96_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.008_c.h3.fld.h5', './output_800eV/K1.965_taper0.008_f.h3.fld.h5', './output_800eV/K1.9660000000000002_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.006_d.h3.fld.h5', './output_800eV/K1.698_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.006_c.h3.fld.h5', './output_800eV/K1.969_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.0_d.h3.fld.h5', './output_800eV/K1.965_taper0.002_PS1.h3.fld.h5', './output_800eV/K1.965_taper0.006_b.h3.fld.h5', './output_800eV/K1.965_taper0.01_d.h3.fld.h5', './output_800eV/K1.965_taper0.004_c.h3.fld.h5', './output_800eV/K1.965_taper0.01_PS1.h3.fld.h5', './output_800eV/K1.702_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.002_PS2.h3.fld.h5', './output_800eV/K1.965_taper0.01_f.h3.fld.h5', './output_800eV/K1.965_taper0.0_PS1.h3.fld.h5', './output_800eV/K1.965_taper0.01_b.h3.fld.h5', './output_800eV/K1.965_taper0.002_b.h3.fld.h5', './output_800eV/K1.965_taper0.008_PS2.h3.fld.h5', './output_800eV/K1.9609999999999999_taper0.0_a.h3.fld.h5', './output_800eV/K1.962_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.002_f.h3.fld.h5', './output_800eV/K1.964_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.004_b.h3.fld.h5', './output_800eV/K1.963_taper0.0_a.h3.fld.h5', './output_800eV/K1.706_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.0_a.h3.fld.h5', './output_800eV/K1.71_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.006_PS1.h3.fld.h5', './output_800eV/K1.965_taper0.0_b.h3.fld.h5', './output_800eV/K1.965_taper0.002_c.h3.fld.h5', './output_800eV/K1.965_taper0.008_b.h3.fld.h5', './output_800eV/K1.967_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.01_PS2.h3.fld.h5', './output_800eV/K1.965_taper0.004_PS2.h3.fld.h5', './output_800eV/K1.965_taper0.006_PS2.h3.fld.h5', './output_800eV/K1.69_taper0.0_a.h3.fld.h5', './output_800eV/K1.968_taper0.0_a.h3.fld.h5', './output_800eV/K1.965_taper0.006_f.h3.fld.h5', './output_800eV/K1.965_taper0.004_PS1.h3.fld.h5', './output_800eV/K1.965_taper0.004_f.h3.fld.h5', './output_800eV/K1.965_taper0.008_d.h3.fld.h5', './output_800eV/K1.965_taper0.0_c.h3.fld.h5', './output_800eV/K1.965_taper0.0_PS2.h3.fld.h5', './output_800eV/K1.965_taper0.0_f.h3.fld.h5', './output_800eV/K1.965_taper0.008_PS1.h3.fld.h5', './output_800eV/K1.965_taper0.006_f.fld.h5', './output_800eV/K1.965_taper0.008_f.fld.h5', './output_800eV/K1.694_taper0.0_a.fld.h5', './output_800eV/K1.967_taper0.0_a.fld.h5', './output_800eV/K1.698_taper0.0_a.fld.h5', './output_800eV/K1.69_taper0.0_a.fld.h5', './output_800eV/K1.963_taper0.0_a.fld.h5', './output_800eV/K1.964_taper0.0_a.fld.h5', './output_800eV/K1.96_taper0.0_a.fld.h5', './output_800eV/K1.9660000000000002_taper0.0_a.fld.h5', './output_800eV/K1.71_taper0.0_a.fld.h5', './output_800eV/K1.969_taper0.0_a.fld.h5', './output_800eV/K1.965_taper0.0_a.fld.h5', './output_800eV/K1.968_taper0.0_a.fld.h5', './output_800eV/K1.962_taper0.0_a.fld.h5', './output_800eV/K1.706_taper0.0_a.fld.h5', './output_800eV/K1.9609999999999999_taper0.0_a.fld.h5', './output_800eV/K1.702_taper0.0_a.fld.h5', './output_800eV/K1.965_taper0.01_PS1.fld.h5', './output_800eV/K1.965_taper0.002_f.fld.h5', './output_800eV/K1.965_taper0.008_d.fld.h5', './output_800eV/K1.965_taper0.008_b.fld.h5', './output_800eV/K1.965_taper0.002_PS1.fld.h5', './output_800eV/K1.965_taper0.008_PS2.fld.h5', './output_800eV/K1.965_taper0.0_d.fld.h5', ' ...
# outfile                   ./output_800eV/K1.965_taper0.002_test.out.h5
# particle_files            ['./output_800eV/K1.965_taper0.008_c.par.h5', './output_800eV/K1.965_taper0.002_test.par.h5', './output_800eV/K1.965_taper0.0_PS1.par.h5', './output_800eV/K1.965_taper0.002_d.par.h5', './output_800eV/K1.965_taper0.006_b.par.h5', './output_800eV/K1.965_taper0.004_PS2.par.h5', './output_800eV/K1.965_taper0.004_b.par.h5', './output_800eV/K1.965_taper0.002_c.par.h5', './output_800eV/K1.965_taper0.0_f.par.h5', './output_800eV/K1.965_taper0.006_f.par.h5', './output_800eV/K1.965_taper0.008_f.par.h5', './output_800eV/K1.965_taper0.01_test.par.h5', './output_800eV/K1.698_taper0.0_a.par.h5', './output_800eV/K1.968_taper0.0_a.par.h5', './output_800eV/K1.702_taper0.0_a.par.h5', './output_800eV/K1.71_taper0.0_a.par.h5', './output_800eV/K1.969_taper0.0_a.par.h5', './output_800eV/K1.69_taper0.0_a.par.h5', './output_800eV/K1.965_taper0.0_a.par.h5', './output_800eV/K1.967_taper0.0_a.par.h5', './output_800eV/K1.694_taper0.0_a.par.h5', './output_800eV/K1.706_taper0.0_a.par.h5', './output_800eV/K1.9660000000000002_taper0.0_a.par.h5', './output_800eV/K1.962_taper0.0_a.par.h5', './output_800eV/K1.963_taper0.0_a.par.h5', './output_800eV/K1.964_taper0.0_a.par.h5', './output_800eV/K1.96_taper0.0_a.par.h5', './output_800eV/K1.9609999999999999_taper0.0_a.par.h5', './output_800eV/K1.965_taper0.006_test.par.h5', './output_800eV/K1.965_taper0.01_PS1.par.h5', './output_800eV/K1.965_taper0.002_f.par.h5', './output_800eV/K1.965_taper0.008_d.par.h5', './output_800eV/K1.965_taper0.008_b.par.h5', './output_800eV/K1.965_taper0.002_PS1.par.h5', './output_800eV/K1.965_taper0.008_PS2.par.h5', './output_800eV/K1.965_taper0.0_d.par.h5', './output_800eV/K1.965_taper0.008_PS1.par.h5', './output_800eV/K1.965_taper0.006_PS2.par.h5', './output_800eV/K1.965_taper0.0_b.par.h5', './output_800eV/K1.965_taper0.004_c.par.h5', './output_800eV/K1.965_taper0.004_test.par.h5', './output_800eV/K1.965_taper0.006_PS1.par.h5', './output_800eV/K1.965_taper0.006_c.par.h5', './output_800eV/K1.965_taper0.004_f.par.h5', './output_800eV/K1.965_taper0.01_c.par.h5', './output_800eV/K1.965_taper0.01_f.par.h5', './output_800eV/K1.965_taper0.006_d.par.h5', './output_800eV/K1.965_taper0.002_PS2.par.h5', './output_800eV/K1.965_taper0.004_d.par.h5', './output_800eV/K1.965_taper0.008_test.par.h5', './output_800eV/K1.965_taper0.004_PS1.par.h5', './output_800eV/K1.965_taper0.01_d.par.h5', './output_800eV/K1.965_taper0.01_b.par.h5', './output_800eV/K1.965_taper0.0_test.par.h5', './output_800eV/K1.965_taper0.002_b.par.h5', './output_800eV/K1.965_taper0.0_PS2.par.h5', './output_800eV/K1.965_taper0.01_PS2.par.h5', './output_800eV/K1.965_taper0.0_c.par.h5']

# %%
pulselen = 80e-15
sigma = 5e-15
peak_current = 2.0e3
NPTS = 1000
cspeed  = 299792458
SLEN = pulselen*cspeed
sigma_z = sigma*cspeed

S = np.linspace(0, SLEN, NPTS)

CURRENT = np.ones((NPTS,))*peak_current
CURRENT[S > SLEN/2 + sigma_z] = 0
CURRENT[S < SLEN/2 - sigma_z] = 0

# %%
plt.plot(S, CURRENT)

# %%
import numpy as np
xlamds = (1.55e-9)/3
xlamdu = 0.039
gam0 = np.around(3990./0.511,3)
np.sqrt(xlamds/xlamdu*2*gam0**2-1)
# Out:
# 0.7844736939534364
